# %%
import pandas as pd 
import numpy as np
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

from functools import partial
import optuna


def optimize(trial,x,y):
    criterion = trial.suggest_categorical("criterion",["gini","entropy"])
    n_estimators = trial.suggest_int("n_estimators",100,1500)
    max_depth = trial.suggest_int("max_depth",3,15)
    max_features = trial.suggest_uniform("max_features",0.01,1.0)

    model = ensemble.RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion
    )
    
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x,y=y):
        train_idx,test_idx = idx[0], idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]

        xtest = x[test_idx]
        ytest = y[test_idx]

        model.fit(xtrain,ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest,preds)
        accuracies.append(fold_acc)

    return -1.0*np.mean(accuracies)


if __name__ == "__main__":
    df = pd.read_csv("/Users/yunbo/Documents/GitHub/Machine-learning-learning-and-code-practice/Hyper_parameter_tuning/input/train.csv")
    X = df.drop("price_range",axis=1).values
    y = df.price_range.values
    optimization_function = partial(optimize,x=X,y=y)
    
    study = optuna.create_study(direction="minimize")
    study.optimize(optimization_function,n_trials=15)
# Out:
# [I 2024-02-08 12:23:10,042] A new study created in memory with name: no-name-65551094-961c-4e10-b05a-4e98a0c37392
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:23:33,902] Trial 0 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 996, 'max_depth': 9, 'max_features': 0.9791782139181651}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:23:37,305] Trial 1 finished with value: -0.8925000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 308, 'max_depth': 8, 'max_features': 0.30044753370659677}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:23:42,067] Trial 2 finished with value: -0.8504999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 636, 'max_depth': 12, 'max_features': 0.11793269844072607}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:23:55,754] Trial 3 finished with value: -0.8905 and parameters: {'criterion': 'gini', 'n_estimators': 687, 'max_depth': 7, 'max_features': 0.9332112533601034}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:24:19,356] Trial 4 finished with value: -0.8945000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 1239, 'max_depth': 8, 'max_features': 0.8441238732616172}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:24:43,113] Trial 5 finished with value: -0.9045 and parameters: {'criterion': 'gini', 'n_estimators': 1419, 'max_depth': 14, 'max_features': 0.6221904038267159}. Best is trial 0 with value: -0.906.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:24:48,863] Trial 6 finished with value: -0.9065 and parameters: {'criterion': 'gini', 'n_estimators': 346, 'max_depth': 14, 'max_features': 0.6162973121046607}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:24:56,276] Trial 7 finished with value: -0.8265 and parameters: {'criterion': 'entropy', 'n_estimators': 1370, 'max_depth': 7, 'max_features': 0.13421832663712832}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:25:15,602] Trial 8 finished with value: -0.8939999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 993, 'max_depth': 8, 'max_features': 0.8096957918564803}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:25:26,813] Trial 9 finished with value: -0.9019999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 526, 'max_depth': 7, 'max_features': 0.877771621200122}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:25:27,695] Trial 10 finished with value: -0.7965 and parameters: {'criterion': 'gini', 'n_estimators': 126, 'max_depth': 3, 'max_features': 0.5112583207913413}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:25:44,876] Trial 11 finished with value: -0.9055 and parameters: {'criterion': 'entropy', 'n_estimators': 982, 'max_depth': 11, 'max_features': 0.6234293645345066}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:25:57,287] Trial 12 finished with value: -0.9005000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 925, 'max_depth': 15, 'max_features': 0.3559027091902572}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:26:04,420] Trial 13 finished with value: -0.9019999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 415, 'max_depth': 11, 'max_features': 0.6512623253393628}. Best is trial 6 with value: -0.9065.
# /var/folders/_y/0xw7_0ss0s3f4kfhj9xl96zw0000gn/T/ipykernel_33620/3026766003.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform("max_features",0.01,1.0)
# [I 2024-02-08 12:26:06,772] Trial 14 finished with value: -0.8305 and parameters: {'criterion': 'entropy', 'n_estimators': 150, 'max_depth': 4, 'max_features': 0.9855240052553245}. Best is trial 6 with value: -0.9065.
